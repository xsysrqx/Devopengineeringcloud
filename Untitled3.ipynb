# %% [markdown]
# <a href="https://colab.research.google.com/github/xsysrqx/Devopengineeringcloud/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot  as plt


category=["travel","Foood","Sightingseeing", "shopping", "Gaming"]
expense=[10000,20000,30000,40000,50000]

fig, ax= plt.subplots()
ax.set_title("My expense")
ax.pie(expense, labels=category, autopct="%.1f%%")

plt.show()

# %%
import seaborn as sns

df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.displot(x="age", data=df)

# %%
sns.scatterplot(x='embarked', y='sex', data=df)
# Out:
# <Axes: xlabel='embarked', ylabel='sex'>

# %%
import seaborn as sns

df = sns.load_dataset('youtube')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-4c95c173e718> in <cell line: 3>()
#       1 import seaborn as sns
#       2
# ----> 3 df = sns.load_dataset('youtube')
#       4 df.head()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     585         if not os.path.exists(cache_path):
#     586             if name not in get_dataset_names():
# --> 587                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     588             urlretrieve(url, cache_path)
#     589         full_path = cache_path
#
# ValueError: 'youtube' is not one of the example datasets.

# %%
import pandas as pd
df0 = pd.DataFrame({'Company Name':['Google', 'Microsoft', 'Space', 'Amazon', 'Samsung'],
                   'Founders':['Larry Page, Sergey Brin', 'Bill Gates, Paul Allen', 'Elon Musk', 'Jeff Bezos', 'Lee Byung-chul'],
                   'Founded': [1998, 1975, 2002, 1994, 1938],
                   'Number of Employees': ['103,459','144,106', '6,500','647,500','320,671']})
df0
# Out:
#   Company Name                 Founders  Founded Number of Employees
# 0       Google  Larry Page, Sergey Brin     1998             103,459
# 1    Microsoft   Bill Gates, Paul Allen     1975             144,106
# 2        Space                Elon Musk     2002               6,500
# 3       Amazon               Jeff Bezos     1994             647,500
# 4      Samsung           Lee Byung-chul     1938             320,671

# %%
df1 = pd.DataFrame({'Company Name':['WhatsApp'], 'Founders':['Jan Koum, Brian Acton'], 'Founded': [2009], 'Number of Employees':['50']})
df1
# Out:
#   Company Name               Founders  Founded Number of Employees
# 0     WhatsApp  Jan Koum, Brian Acton     2009                  50

# %%
df0 = df0.append(df1, ignore_index=True)
df0
# Out:
# <ipython-input-5-ae9519a98806>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df0 = df0.append(df1, ignore_index=True)
#   Company Name                 Founders  Founded Number of Employees
# 0       Google  Larry Page, Sergey Brin     1998             103,459
# 1    Microsoft   Bill Gates, Paul Allen     1975             144,106
# 2        Space                Elon Musk     2002               6,500
# 3       Amazon               Jeff Bezos     1994             647,500
# 4      Samsung           Lee Byung-chul     1938             320,671
# 5     WhatsApp    Jan Koum, Brian Acton     2009                  50

# %%
df0.iloc[3] = ['Youtube', 'Chad Hurley, Steve Chen, Jawed Karim', 2005, '2,800']
df0
# Out:
#   Company Name                              Founders  Founded  \
# 0       Google               Larry Page, Sergey Brin     1998
# 1    Microsoft                Bill Gates, Paul Allen     1975
# 2        Space                             Elon Musk     2002
# 3      Youtube  Chad Hurley, Steve Chen, Jawed Karim     2005
# 4      Samsung                        Lee Byung-chul     1938
# 5     WhatsApp                 Jan Koum, Brian Acton     2009
#
#   Number of Employees
# 0             103,459
# 1             144,106
# 2               6,500
# 3               2,800
# 4             320,671
# 5                  50

# %%
df0 = df0.drop([df0.index[5]])
df0
# Out:
#   Company Name                              Founders  Founded  \
# 0       Google               Larry Page, Sergey Brin     1998
# 1    Microsoft                Bill Gates, Paul Allen     1975
# 2        Space                             Elon Musk     2002
# 3      Youtube  Chad Hurley, Steve Chen, Jawed Karim     2005
# 4      Samsung                        Lee Byung-chul     1938
#
#   Number of Employees
# 0             103,459
# 1             144,106
# 2               6,500
# 3               2,800
# 4             320,671

# %%
df0
# Out:
#   Company Name                              Founders  Founded  \
# 0       Google               Larry Page, Sergey Brin     1998
# 1    Microsoft                Bill Gates, Paul Allen     1975
# 2        Space                             Elon Musk     2002
# 3      Youtube  Chad Hurley, Steve Chen, Jawed Karim     2005
# 4      Samsung                        Lee Byung-chul     1938
#
#   Number of Employees
# 0             103,459
# 1             144,106
# 2               6,500
# 3               2,800
# 4             320,671

# %%
df0 = df0[df0.Founders != 'Chad Hurley, Steve Chen, Jawed Karim']

# %%
df0
# Out:
#   Company Name                 Founders  Founded Number of Employees
# 0       Google  Larry Page, Sergey Brin     1998             103,459
# 1    Microsoft   Bill Gates, Paul Allen     1975             144,106
# 2        Space                Elon Musk     2002               6,500
# 4      Samsung           Lee Byung-chul     1938             320,671

# %%
df0.loc[2]
# Out:
# Company Name               Space
# Founders               Elon Musk
# Founded                     2002
# Number of Employees        6,500
# Name: 2, dtype: object

# %%
df0.at[1, 'Number of Employees'] = '200,000'
df0 # This is after the change of value (Microsoft)
# Out:
#   Company Name                 Founders  Founded Number of Employees
# 0       Google  Larry Page, Sergey Brin     1998             103,459
# 1    Microsoft   Bill Gates, Paul Allen     1975             200,000
# 2        Space                Elon Musk     2002               6,500
# 4      Samsung           Lee Byung-chul     1938             320,671

# %% [markdown]
# # New Section
